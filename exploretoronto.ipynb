# %% [markdown]
# Please provide a valuable feedback if you are reducing points

# %% [markdown]
# Scraping method:Use pandas to read the table into a pandas dataframe

# %%
import pandas as pd
d=pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
df_neighbor=d[0]
df_neighbor.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# Code to Ignore cells with a borough that is Not assigned

# %%
df_neighbor=df_neighbor.set_index('Borough')
df_neighbor=df_neighbor.drop("Not assigned", axis=0)

# %%
df1=df_neighbor.reset_index()

df1.head()
# Out:
#             Borough Postcode     Neighbourhood
# 0        North York      M3A         Parkwoods
# 1        North York      M4A  Victoria Village
# 2  Downtown Toronto      M5A      Harbourfront
# 3  Downtown Toronto      M5A       Regent Park
# 4        North York      M6A  Lawrence Heights

# %%
#swapped column names
df2=df1[['Postcode','Borough','Neighbourhood']]
df2.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights

# %% [markdown]
# Group rows into unique row with postcode and neighborhoods separated with a comma

# %%
df3=df2.groupby(['Postcode','Borough'])['Neighbourhood'].apply(','.join).reset_index()
df3.head()
# Out:
#   Postcode      Borough                         Neighbourhood
# 0      M1B  Scarborough                         Rouge,Malvern
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill
# 3      M1G  Scarborough                                Woburn
# 4      M1H  Scarborough                             Cedarbrae

# %% [markdown]
# Replacing Not assigned neighborhood with corresponding Borough values

# %%
df3['Neighbourhood'][df3['Neighbourhood']=='Not assigned']=df3['Borough']

# %% [markdown]
# Renamed column to Postal code

# %%
#final dataframe
df4=df3.rename(columns={'Postcode':'Postal Code'})
df4
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# ...

# %%
df4.shape
# Out:
# (103, 3)

# %% [markdown]
# Read csv file with geospatial data to new dataframe-(starts 2nd submission)

# %%
df5=pd.read_csv('http://cocl.us/Geospatial_data')
df5
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %% [markdown]
# Merge previous dataframe with new dataframe to form dataframe with all deatils

# %%
df6=pd.merge(left=df4,right=df5,left_on='Postal Code',right_on='Postal Code')
df6
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# ...

# %% [markdown]
# Explore and cluster neighbourhoods of Toronto(starts 3rd submission)

# %% [markdown]
# select Borough that contains word Toronto

# %%
df7 =  df6[df6['Borough'].str.contains('Toronto')].reset_index(drop=True)
df7
# Out:
#    Postal Code           Borough  \
# 0          M4E      East Toronto
# 1          M4K      East Toronto
# 2          M4L      East Toronto
# 3          M4M      East Toronto
# 4          M4N   Central Toronto
# 5          M4P   Central Toronto
# 6          M4R   Central Toronto
# 7          M4S   Central Toronto
# 8          M4T   Central Toronto
# 9          M4V   Central Toronto
# 10         M4W  Downtown Toronto
# 11         M4X  Downtown Toronto
# 12         M4Y  Downtown Toronto
# 13         M5A  Downtown Toronto
# 14         M5B  Downtown Toronto
# 15         M5C  Downtown Toronto
# 16         M5E  Downtown Toronto
# 17         M5G  Downtown Toronto
# 18         M5H  Downtown Toronto
# 19         M5J  Downtown Toronto
# 20         M5K  Downtown Toronto
# 21         M5L  Downtown Toronto
# 22         M5N   Central Toronto
# 23         M5P   Central Toronto
# 24         M5R   Central Toronto
# 25         M5S  Downtown Toronto
# 26         M5T  Downtown Toronto
# ...

# %%
#removed postalcode column for making analysis simple
df8=df7.drop(['Postal Code'],axis=1)
df8.head()
# Out:
#            Borough                  Neighbourhood   Latitude  Longitude
# 0     East Toronto                    The Beaches  43.676357 -79.293031
# 1     East Toronto    The Danforth West,Riverdale  43.679557 -79.352188
# 2     East Toronto  The Beaches West,India Bazaar  43.668999 -79.315572
# 3     East Toronto                Studio District  43.659526 -79.340923
# 4  Central Toronto                  Lawrence Park  43.728020 -79.388790

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df8['Borough'].unique()),
        df8.shape[0]
    )
)
# Out:
# The dataframe has 4 boroughs and 38 neighborhoods.

# %% [markdown]
# Import libraries to explore neighbourhoods of Toronto

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values


# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# ...

# %% [markdown]
# Use geopy library to get the latitude and longitude values of Toronto

# %%
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# Create a map of Toronto with neighborhoods superimposed on top

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map

for lat, lng, borough, neighbourhood in zip(df8['Latitude'], df8['Longitude'], df8['Borough'], df8['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto) 
    #print(lat)
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Apply k-means clustering to group the neighbourhoods

# %%
df9=df8.drop(['Borough','Neighbourhood'],axis=1)
df9.head()
# Out:
#     Latitude  Longitude
# 0  43.676357 -79.293031
# 1  43.679557 -79.352188
# 2  43.668999 -79.315572
# 3  43.659526 -79.340923
# 4  43.728020 -79.388790

# %%
kclusters=4
kmeans = KMeans(init="k-means++", n_clusters=4, n_init=12).fit(df9)
kmeans.labels_[0:10]
# Out:
# array([3, 3, 3, 3, 2, 2, 2, 2, 2, 2], dtype=int32)

# %% [markdown]
# Add cluster labels to cleaned dataframe

# %%
#create a copy of df8 
local_df = df8.copy(deep=True)
local_df.head()
# Out:
#            Borough                  Neighbourhood   Latitude  Longitude
# 0     East Toronto                    The Beaches  43.676357 -79.293031
# 1     East Toronto    The Danforth West,Riverdale  43.679557 -79.352188
# 2     East Toronto  The Beaches West,India Bazaar  43.668999 -79.315572
# 3     East Toronto                Studio District  43.659526 -79.340923
# 4  Central Toronto                  Lawrence Park  43.728020 -79.388790

# %%
# insert cluster labels to new df
local_df.insert(0,"Cluster labels",kmeans.labels_)
local_df.head()
# Out:
#    Cluster labels          Borough                  Neighbourhood   Latitude  \
# 0               3     East Toronto                    The Beaches  43.676357
# 1               3     East Toronto    The Danforth West,Riverdale  43.679557
# 2               3     East Toronto  The Beaches West,India Bazaar  43.668999
# 3               3     East Toronto                Studio District  43.659526
# 4               2  Central Toronto                  Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %% [markdown]
# create dataframes for each cluster

# %%
dataframe_cluster0=local_df.loc[local_df['Cluster labels']==0]
dataframe_cluster1=local_df.loc[local_df['Cluster labels']==1]
dataframe_cluster2=local_df.loc[local_df['Cluster labels']==2]
dataframe_cluster3=local_df.loc[local_df['Cluster labels']==3]

# %%
dataframe_cluster0.head()
# Out:
#     Cluster labels           Borough               Neighbourhood   Latitude  \
# 10               0  Downtown Toronto                    Rosedale  43.679563
# 11               0  Downtown Toronto  Cabbagetown,St. James Town  43.667967
# 12               0  Downtown Toronto        Church and Wellesley  43.665860
# 13               0  Downtown Toronto    Harbourfront,Regent Park  43.654260
# 14               0  Downtown Toronto     Ryerson,Garden District  43.657162
#
#     Longitude
# 10 -79.377529
# 11 -79.367675
# 12 -79.383160
# 13 -79.360636
# 14 -79.378937

# %%
dataframe_cluster1.head()
# Out:
#     Cluster labels           Borough  \
# 30               1  Downtown Toronto
# 31               1      West Toronto
# 32               1      West Toronto
# 33               1      West Toronto
# 34               1      West Toronto
#
#                                  Neighbourhood   Latitude  Longitude
# 30                                    Christie  43.669542 -79.422564
# 31                 Dovercourt Village,Dufferin  43.669005 -79.442259
# 32                     Little Portugal,Trinity  43.647927 -79.419750
# 33  Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 34                High Park,The Junction South  43.661608 -79.464763

# %%
dataframe_cluster2.head()
# Out:
#    Cluster labels          Borough               Neighbourhood   Latitude  \
# 4               2  Central Toronto               Lawrence Park  43.728020
# 5               2  Central Toronto            Davisville North  43.712751
# 6               2  Central Toronto          North Toronto West  43.715383
# 7               2  Central Toronto                  Davisville  43.704324
# 8               2  Central Toronto  Moore Park,Summerhill East  43.689574
#
#    Longitude
# 4 -79.388790
# 5 -79.390197
# 6 -79.405678
# 7 -79.388790
# 8 -79.383160

# %%
dataframe_cluster3.head()
# Out:
#     Cluster labels       Borough  \
# 0                3  East Toronto
# 1                3  East Toronto
# 2                3  East Toronto
# 3                3  East Toronto
# 37               3  East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                         The Beaches  43.676357 -79.293031
# 1                         The Danforth West,Riverdale  43.679557 -79.352188
# 2                       The Beaches West,India Bazaar  43.668999 -79.315572
# 3                                     Studio District  43.659526 -79.340923
# 37  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %%
#display shape each cluster
print('Cluster 0',dataframe_cluster0.shape)
print('Cluster 1',dataframe_cluster1.shape)
print('Cluster 2',dataframe_cluster2.shape)
print('Cluster 3',dataframe_cluster3.shape)
# Out:
# Cluster 0 (18, 5)
# Cluster 1 (7, 5)
# Cluster 2 (8, 5)
# Cluster 3 (5, 5)

# %% [markdown]
# Generate map to visualize the clustered neighbourhoods

# %% [markdown]
# Centroids of cluster is displayed as a black circle mark. Spots in cluster 0 is displayed in blue. Spots in cluster 1 is displayed in red. Spots in cluster 2 is displayed in green.Spots in cluster 3 is displayed in yellow.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10) # generate map centred around City




# add spots in cluster 0 to the map as blue circle markers
for lat, lng,  borough, neighbourhood in zip(dataframe_cluster0['Latitude'], dataframe_cluster0['Longitude'], 
                                           dataframe_cluster0['Borough'], dataframe_cluster0['Neighbourhood']):
    label = '{}, {}'.format(borough, neighbourhood)
    label = folium.Popup(label, parse_html=True)    
    folium.CircleMarker(
        [lat, lng],
        radius=2,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# add spots in cluster 1 to the map as red circle markers
for lat, lng, borough, neighbourhood in zip(dataframe_cluster1['Latitude'], dataframe_cluster1['Longitude'], 
                                           dataframe_cluster1['Borough'], dataframe_cluster1['Neighbourhood']):
    label = '{}, {}'.format(borough, neighbourhood)
    label = folium.Popup(label, parse_html=True)    
    folium.CircleMarker(
        [lat, lng],
        radius=2,
        popup=label,
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)
    
# add spots in cluster 2 to the map as green circle markers
for lat, lng, borough, neighbourhood in zip(dataframe_cluster2['Latitude'], dataframe_cluster2['Longitude'], 
                                           dataframe_cluster2['Borough'], dataframe_cluster2['Neighbourhood']):
    label = '{}, {}'.format(borough, neighbourhood)
    label = folium.Popup(label, parse_html=True)    
    folium.CircleMarker(
        [lat,lng],
        radius=2,
        popup=label,
        fill=True,
        color='green',
        fill_color='green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto) 
# add spots in cluster 3 to the map as green circle markers
for lat, lng, borough, neighbourhood in zip(dataframe_cluster3['Latitude'], dataframe_cluster3['Longitude'], 
                                           dataframe_cluster3['Borough'], dataframe_cluster3['Neighbourhood']):
    label = '{}, {}'.format(borough, neighbourhood)
    label = folium.Popup(label, parse_html=True)    
    folium.CircleMarker(
        [lat,lng],
        radius=2,
        popup=label,
        fill=True,
        color='yellow',
        fill_color='yellow',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto) 

# display map
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
